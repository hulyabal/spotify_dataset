# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("C:\\Users\\honey\\OneDrive\\Masaüstü\\Vodafone")
from plot_functions import histogram_plot, boxplot_plot

# %%
df = pd.read_csv(r"C:\Users\honey\OneDrive\Masaüstü\Vodafone\data_w_genres.csv")

# %%
df.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# 0  0.290833 -14.448000     0.210389  117.518111  0.389500   38.333333    5
# 1  0.315215 -10.690000     0.176212  103.044154  0.268865   30.576923    5
# 2  0.325786 -15.230714     0.118514   77.375857  0.354857   34.857143    0
# 3  0.275481 -15.639370     0.123200   88.667630  0.372030   34.851852    0
# 4  0.195000 -10.236714     0.098543  122.835857  0.482286   43.000000    5
#
#    mode  count
# 0     1      9
# 1     1     26
# 2     1      7
# 3     1     27
# 4     1      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28680 entries, 0 to 28679
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            28680 non-null  object
#  1   artists           28680 non-null  object
#  2   acousticness      28680 non-null  float64
#  3   danceability      28680 non-null  float64
#  4   duration_ms       28680 non-null  float64
#  5   energy            28680 non-null  float64
#  6   instrumentalness  28680 non-null  float64
#  7   liveness          28680 non-null  float64
#  8   loudness          28680 non-null  float64
#  9   speechiness       28680 non-null  float64
#  10  tempo             28680 non-null  float64
#  11  valence           28680 non-null  float64
#  12  popularity        28680 non-null  float64
#  13  key               28680 non-null  int64
#  14  mode              28680 non-null  int64
#  15  count             28680 non-null  int64
# dtypes: float64(11), int64(3), object(2)
# memory usage: 3.5+ MB

# %%
df.isnull().sum()
# Out:
# genres              0
# artists             0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# key                 0
# mode                0
# count               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['genres', 'artists', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key', 'mode', 'count'],
#       dtype='object')

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  28680.000000  28680.000000  2.868000e+04  28680.000000
# mean       0.498373      0.546490  2.388780e+05      0.497488
# std        0.370614      0.176474  1.211318e+05      0.254885
# min        0.000000      0.000000  1.879550e+04      0.000000
# 25%        0.122296      0.431000  1.823304e+05      0.283568
# 50%        0.478458      0.557000  2.186400e+05      0.504000
# 75%        0.896000      0.675000  2.684670e+05      0.702783
# max        0.996000      0.986000  5.403500e+06      1.000000
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      28680.000000  28680.000000  28680.000000  28680.000000
# mean           0.174756      0.202441    -11.140498      0.094014
# std            0.298406      0.140884      5.771749      0.111986
# min            0.000000      0.000000    -60.000000      0.000000
# 25%            0.000004      0.110362    -13.972292      0.039200
# 50%            0.001880      0.161000    -10.088938      0.052200
# 75%            0.215291      0.247000     -6.889000      0.095300
# max            1.000000      0.991000      1.342000      0.964000
#
#               tempo       valence    popularity           key          mode  \
# count  28680.000000  28680.000000  28680.000000  28680.000000  28680.000000
# mean     115.844830      0.512723     34.060945      5.412901      0.759170
# std       25.003834      0.244421     22.376438      3.480552      0.427595
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       99.366500      0.329000     12.000000      2.000000      1.000000
# 50%      115.357400      0.523243     39.000000      6.000000      1.000000
# 75%      129.848750      0.703000     51.000000      8.000000      1.000000
# max      217.743000      0.991000     93.000000     11.000000      1.000000
#
#               count
# count  28680.000000
# mean      13.847211
# std       53.372544
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        8.000000
# max     3169.000000

# %% [markdown]
# ## FEATURE ANALYSIS

# %% [markdown]
# ### 1. Genres

# %%
df['genres'].describe()
# Out:
# count     28680
# unique    10743
# top          []
# freq       9857
# Name: genres, dtype: object

# %%
df['genres'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 28680 entries, 0 to 28679
# Series name: genres
# Non-Null Count  Dtype
# --------------  -----
# 28680 non-null  object
# dtypes: object(1)
# memory usage: 224.2+ KB

# %%
df['genres'].value_counts(ascending=False)
# Out:
# []                                                                                     9857
# ['movie tunes']                                                                          69
# ['show tunes']                                                                           63
# ['hollywood']                                                                            56
# ['orchestral performance']                                                               50
#                                                                                        ...
# ['nordic orchestra']                                                                      1
# ['avant-garde', 'contemporary classical', 'hungarian contemporary classical']             1
# ['conscious hip hop', 'dancehall', 'lovers rock', 'modern reggae', 'reggae fusion']       1
# ['classic swedish pop', 'danspunk', 'swedish pop']                                        1
# ['chinese indie', 'chinese indie rock']                                                   1
# Name: genres, Length: 10743, dtype: int64

# %%
df['genres'].nunique()
# Out:
# 10743

# %%
df = df[df['genres'].notnull()]  
df['genres'] = df['genres'].str.strip()  
df = df[df['genres'] != '']  

df['genres'] = df['genres'].str.lower()

df['genres'] = df['genres'].str.replace(r"['\[\]]", '', regex=True) 

df['genres'] = df['genres'].apply(lambda x: x.split(',') if ',' in x else [x])  
df['genres'] = df['genres'].apply(lambda x: [i.strip() for i in x]) 

df = df.explode('genres')

genre_counts = df['genres'].value_counts()
print(genre_counts)
# Out:
#                           9857
# rock                       611
# pop                        593
# dance pop                  572
# rap                        516
#                           ...
# minimal melodic techno       1
# chinese jazz                 1
# chanson paillarde            1
# nederlandse hardstyle        1
# chinese indie rock           1
# Name: genres, Length: 2973, dtype: int64

# %%
genre_counts = df['genres'].value_counts()
top_genres = genre_counts.head(20)  
plt.figure(figsize=(8, 3))
plt.bar(top_genres.index, top_genres.values, color='skyblue', edgecolor='black')
plt.xlabel('Genres', fontsize=8, fontweight='bold')
plt.ylabel('Frequency', fontsize=8, fontweight='bold')
plt.title('Top 20 Genres', fontsize=12, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 2. Artists

# %%
df['artists'].value_counts()
# Out:
# Deerhunter         23
# Autechre           19
# Traffic            18
# Galaxie 500        18
# Beat Happening     18
#                    ..
# Joseph Wong         1
# Joseph Wagner       1
# Joseph Stewart      1
# Joseph Stafford     1
# 조정현                 1
# Name: artists, Length: 28680, dtype: int64

# %%
df['artists'].nunique()
# Out:
# 28680

# %%
artist_counts = df['artists'].value_counts()

top_10_artists = artist_counts.head(10)

print("Top 10 artists and their scores (based on the number of songs):")
for artist, count in top_10_artists.items():
    print(f"{artist}: {count}")
# Out:
# Top 10 artists and their scores (based on the number of songs):
# Deerhunter: 23
# Autechre: 19
# Traffic: 18
# Galaxie 500: 18
# Beat Happening: 18
# Unwound: 18
# Cut Copy: 18
# Joe Jackson: 17
# Grouper: 17
# Polvo: 17

# %% [markdown]
# ### 3. Acousticness

# %%
df['acousticness'].describe()
# Out:
# count    74911.000000
# mean         0.396676
# std          0.341268
# min          0.000000
# 25%          0.085570
# 50%          0.295667
# 75%          0.712571
# max          0.996000
# Name: acousticness, dtype: float64

# %%
histogram_plot(df, 'acousticness', 'Acousticness', 'Distribution of Acousticness Scores')

# %%
boxplot_plot(
    data=df,
    column_name='acousticness',
    xlabel='Acousticness',
    title='Boxplot of Acousticness Scores'
)

# %% [markdown]
# ### 4. Danceability

# %%
df['danceability'].nunique()
# Out:
# 10651

# %%
df['danceability'].describe()
# Out:
# count    74911.000000
# mean         0.559031
# std          0.163683
# min          0.000000
# 25%          0.456000
# 50%          0.564000
# 75%          0.676500
# max          0.986000
# Name: danceability, dtype: float64

# %%
histogram_plot(df, 'danceability', 'Danceability', 'Distribution of Danceability Scores')

# %%
boxplot_plot(
    data=df,
    column_name='danceability',
    xlabel='Danceability',
    title='Boxplot of Danceability Scores'
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74911 entries, 0 to 28679
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            74911 non-null  object
#  1   artists           74911 non-null  object
#  2   acousticness      74911 non-null  float64
#  3   danceability      74911 non-null  float64
#  4   duration_ms       74911 non-null  float64
#  5   energy            74911 non-null  float64
#  6   instrumentalness  74911 non-null  float64
#  7   liveness          74911 non-null  float64
#  8   loudness          74911 non-null  float64
#  9   speechiness       74911 non-null  float64
#  10  tempo             74911 non-null  float64
#  11  valence           74911 non-null  float64
#  12  popularity        74911 non-null  float64
#  13  key               74911 non-null  int64
#  14  mode              74911 non-null  int64
#  15  count             74911 non-null  int64
# dtypes: float64(11), int64(3), object(2)
# memory usage: 9.7+ MB

# %% [markdown]
# ### 5.Duration (ms)

# %%
df['duration_ms'].describe()
# Out:
# count    7.491100e+04
# mean     2.440243e+05
# std      9.884551e+04
# min      1.879550e+04
# 25%      1.925182e+05
# 50%      2.303562e+05
# 75%      2.736410e+05
# max      5.403500e+06
# Name: duration_ms, dtype: float64

# %%
df['duration_min'] = df['duration_ms'] / 60000

# %%
df['duration_min'].describe()
# Out:
# count    74911.000000
# mean         4.067072
# std          1.647425
# min          0.313258
# 25%          3.208638
# 50%          3.839270
# 75%          4.560684
# max         90.058333
# Name: duration_min, dtype: float64

# %%
df['duration_min'].value_counts(ascending=False)
# Out:
# 3.582217    27
# 3.644000    26
# 5.345333    25
# 4.480000    23
# 4.960887    23
#             ..
# 5.007117     1
# 5.125783     1
# 3.965266     1
# 3.519183     1
# 3.961467     1
# Name: duration_min, Length: 23960, dtype: int64

# %%
zero_duration_count = (df['duration_min'] == 0).sum()
print("Number of rows with 0 duration:", zero_duration_count)
# Out:
# Number of rows with 0 duration: 0

# %%
plt.figure(figsize=(6, 4))
plt.hist(df['duration_min'], bins=40, edgecolor='black')
plt.title('Distribution of Song Durations', fontsize=10, fontweight='bold')
plt.xlabel('Duration (minutes)', fontsize=8, fontweight='bold')
plt.ylabel('Frequency', fontsize=8, fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.6)
plt.gca().set_facecolor('#f9f9f9')
plt.tight_layout()
plt.show()

# %%
duration_limit = 10
filtered_df = df[df['duration_min'] > duration_limit]
total_count = len(df)
filtered_count = len(filtered_df)
percentage_above_limit = (filtered_count / total_count) * 100

print(f"Percentage of songs with duration > {duration_limit} minutes: {percentage_above_limit:.2f}%")
# Out:
# Percentage of songs with duration > 10 minutes: 0.67%

# %%
duration_limit = 10

df = df[df['duration_min'] <= duration_limit]
df['duration_min'].describe()
# Out:
# count    74410.000000
# mean         3.992924
# std          1.231128
# min          0.313258
# 25%          3.204175
# 50%          3.830667
# 75%          4.537975
# max         10.000000
# Name: duration_min, dtype: float64

# %% [markdown]
# ### 6. Energy

# %%
df['energy'].describe()
# Out:
# count    74410.000000
# mean         0.557411
# std          0.239142
# min          0.000000
# 25%          0.385000
# 50%          0.586000
# 75%          0.740000
# max          1.000000
# Name: energy, dtype: float64

# %%
df['energy'].nunique()
# Out:
# 12033

# %%
df['energy'].value_counts(ascending=False)
# Out:
# 0.74100    92
# 0.69200    87
# 0.70000    85
# 0.54700    83
# 0.69700    81
#            ..
# 0.51445     1
# 0.50075     1
# 0.01800     1
# 0.23730     1
# 0.06924     1
# Name: energy, Length: 12033, dtype: int64

# %%
histogram_plot(df, 'energy', 'Energy', 'Distribution of Energy Scores')

# %%
boxplot_plot(
    data=df,
    column_name='energy',
    xlabel='Energy',
    title='Boxplot of Energy Scores'
)

# %% [markdown]
# ### 7. Instrumentalness

# %%
df['instrumentalness'].describe()
# Out:
# count    74410.000000
# mean         0.147768
# std          0.266177
# min          0.000000
# 25%          0.000011
# 50%          0.002950
# 75%          0.152034
# max          1.000000
# Name: instrumentalness, dtype: float64

# %%
df['instrumentalness'].value_counts(ascending=False)
# Out:
# 0.000000    11178
# 0.907000       65
# 0.872000       47
# 0.916000       47
# 0.893000       44
#             ...
# 0.000064        1
# 0.000095        1
# 0.515284        1
# 0.000008        1
# 0.000083        1
# Name: instrumentalness, Length: 15417, dtype: int64

# %%
df['instrumentalness'].nunique()
# Out:
# 15417

# %%
histogram_plot(df, 'instrumentalness', 'Instrumentalness', 'Distribution of Instrumentalness Scores')

# %%
boxplot_plot(
    data=df,
    column_name='instrumentalness',
    xlabel='Instrumentalness',
    title='Boxplot of Instrumentalness Scores'
)

# %% [markdown]
# ### 8. Liveness

# %%
df['liveness'].describe()
# Out:
# count    74410.000000
# mean         0.196021
# std          0.123225
# min          0.000000
# 25%          0.116000
# 50%          0.166000
# 75%          0.235000
# max          0.991000
# Name: liveness, dtype: float64

# %%
df['liveness'].value_counts(ascending=False)
# Out:
# 0.108000    292
# 0.109000    281
# 0.102000    281
# 0.110000    270
# 0.113000    269
#            ...
# 0.100667      1
# 0.031400      1
# 0.184750      1
# 0.039100      1
# 0.142191      1
# Name: liveness, Length: 12095, dtype: int64

# %%
df['liveness'].nunique()
# Out:
# 12095

# %%
histogram_plot(df, 'liveness', 'Liveness', 'Distribution of Liveness Scores')

# %%
boxplot_plot(
    data=df,
    column_name='liveness',
    xlabel='Liveness',
    title='Boxplot of Liveness Scores'
)

# %% [markdown]
# ### 9. Loudness

# %%
df['loudness'].describe()
# Out:
# count    74410.000000
# mean       -10.075689
# std          5.179846
# min        -60.000000
# 25%        -12.474500
# 50%         -9.035167
# 75%         -6.333000
# max          1.342000
# Name: loudness, dtype: float64

# %%
df['loudness'].value_counts(ascending=False)
# Out:
# -9.762000     29
# -4.311000     28
# -7.497000     27
# -7.252000     25
# -12.357000    25
#               ..
# -19.730333     1
# -7.293000      1
# -14.621000     1
# -15.585667     1
# -16.478000     1
# Name: loudness, Length: 21673, dtype: int64

# %%
df['loudness']
# Out:
# 0       -14.448000
# 1       -10.690000
# 2       -15.230714
# 3       -15.639370
# 4       -10.236714
#            ...
# 28676   -11.974000
# 28677   -21.610091
# 28678    -9.103000
# 28678    -9.103000
# 28679   -16.478000
# Name: loudness, Length: 74410, dtype: float64

# %%
histogram_plot(df, 'loudness', 'Loudness', 'Distribution of Loudness Scores')

# %% [markdown]
# ### 10. Speechiness

# %%
df['speechiness'].describe()
# Out:
# count    74410.000000
# mean         0.087019
# std          0.092147
# min          0.000000
# 25%          0.039350
# 50%          0.051922
# 75%          0.090700
# max          0.960909
# Name: speechiness, dtype: float64

# %%
df['speechiness'].value_counts(ascending=False)
# Out:
# 0.035200    145
# 0.034900    130
# 0.036700    121
# 0.037600    117
# 0.039700    116
#            ...
# 0.110500      1
# 0.134767      1
# 0.408000      1
# 0.036325      1
# 0.054355      1
# Name: speechiness, Length: 10889, dtype: int64

# %%
df['speechiness'].nunique()
# Out:
# 10889

# %%
histogram_plot(df, 'speechiness', 'Speechiness', 'Distribution of Speechiness Scores')

# %%
boxplot_plot(
    data=df,
    column_name='speechiness',
    xlabel='Speechiness',
    title='Boxplot of Speechiness Scores'
)

# %% [markdown]
# ### 11. Tempo

# %%
df['tempo'].describe()
# Out:
# count    74410.000000
# mean       118.240589
# std         22.325168
# min          0.000000
# 25%        104.806938
# 50%        118.048500
# 75%        129.996750
# max        217.743000
# Name: tempo, dtype: float64

# %%
df['tempo'].value_counts(ascending=False)
# Out:
# 0.000000      53
# 74.622000     25
# 125.391250    24
# 110.443400    23
# 124.098333    23
#               ..
# 118.283600     1
# 105.245000     1
# 103.044154     1
# 136.002000     1
# 71.979000      1
# Name: tempo, Length: 24581, dtype: int64

# %%
df['tempo'].nunique()
# Out:
# 24581

# %%
histogram_plot(df, 'tempo', 'Tempo', 'Distribution of Tempo Scores')

# %% [markdown]
# ### 12. Valence

# %%
df['valence'].nunique()
# Out:
# 11783

# %%
df['valence'].describe()
# Out:
# count    74410.000000
# mean         0.523585
# std          0.222500
# min          0.000000
# 25%          0.368000
# 50%          0.533000
# 75%          0.687000
# max          0.991000
# Name: valence, dtype: float64

# %%
df['valence']
# Out:
# 0        0.389500
# 1        0.268865
# 2        0.354857
# 3        0.372030
# 4        0.482286
#            ...
# 28676    0.243000
# 28677    0.741273
# 28678    0.352000
# 28678    0.352000
# 28679    0.177000
# Name: valence, Length: 74410, dtype: float64

# %%
histogram_plot(df, 'valence', 'Valence', 'Distribution of Valence Scores')

# %%
valence_data = df['valence']

high_count = valence_data[valence_data >= 0.5].count()
low_count = valence_data[valence_data < 0.5].count()
total_count = high_count + low_count

high_percentage = (high_count / total_count) * 100
low_percentage = (low_count / total_count) * 100

labels = ['High Valence (>= 0.5)', 'Low Valence (< 0.5)']
sizes = [high_percentage, low_percentage]
colors = ['skyblue', 'salmon']

plt.figure(figsize=(4, 4))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title('Distribution of High and Low Valence Scores', fontsize=10, fontweight='bold')

plt.show()

# %% [markdown]
# ### 13. Popularity

# %%
df['popularity'].describe()
# Out:
# count    74410.000000
# mean        39.760575
# std         18.921463
# min          0.000000
# 25%         31.000000
# 50%         43.000000
# 75%         53.000000
# max         93.000000
# Name: popularity, dtype: float64

# %%
df['popularity'].value_counts(ascending=False)
# Out:
# 0.000000     5073
# 50.000000     929
# 46.000000     897
# 43.000000     896
# 52.000000     894
#              ...
# 6.847222        1
# 26.600000       1
# 0.149351        1
# 0.611111        1
# 3.523810        1
# Name: popularity, Length: 4654, dtype: int64

# %%
df['popularity'].nunique()
# Out:
# 4654

# %%
histogram_plot(df, 'popularity', 'Popularity', 'Distribution of Popularity Scores')

# %% [markdown]
# ### 14. Key

# %%
df['key'].describe()
# Out:
# count    74410.000000
# mean         5.478081
# std          3.505875
# min          0.000000
# 25%          2.000000
# 50%          6.000000
# 75%          9.000000
# max         11.000000
# Name: key, dtype: float64

# %%
df['key'].value_counts(ascending=False)
# Out:
# 7     11172
# 2      7681
# 9      7669
# 0      7571
# 5      6817
# 1      6343
# 11     6283
# 4      5049
# 10     5013
# 6      4708
# 8      3722
# 3      2382
# Name: key, dtype: int64

# %%
df['key'].nunique()
# Out:
# 12

# %%
key_counts = df['key'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(6, 4))
bars = plt.bar(key_counts.index, key_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('Key', fontsize=8, fontweight='bold')
plt.ylabel('Frequency', fontsize=8, fontweight='bold')
plt.title('Distribution of Music Keys', fontsize=12, fontweight='bold')
plt.xticks(key_counts.index)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()


for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() +50, 
             f'{int(bar.get_height())}', ha='center', va='bottom', 
             fontsize=8, fontweight='bold')

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74410 entries, 0 to 28679
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            74410 non-null  object
#  1   artists           74410 non-null  object
#  2   acousticness      74410 non-null  float64
#  3   danceability      74410 non-null  float64
#  4   duration_ms       74410 non-null  float64
#  5   energy            74410 non-null  float64
#  6   instrumentalness  74410 non-null  float64
#  7   liveness          74410 non-null  float64
#  8   loudness          74410 non-null  float64
#  9   speechiness       74410 non-null  float64
#  10  tempo             74410 non-null  float64
#  11  valence           74410 non-null  float64
#  12  popularity        74410 non-null  float64
#  13  key               74410 non-null  int64
#  14  mode              74410 non-null  int64
#  15  count             74410 non-null  int64
#  16  duration_min      74410 non-null  float64
# dtypes: float64(12), int64(3), object(2)
# memory usage: 10.2+ MB

# %% [markdown]
# ### 15. Mode

# %%
df['mode'].describe()
# Out:
# count    74410.00000
# mean         0.76827
# std          0.42194
# min          0.00000
# 25%          1.00000
# 50%          1.00000
# 75%          1.00000
# max          1.00000
# Name: mode, dtype: float64

# %%
df['mode'].value_counts(ascending=False)
# Out:
# 1    57167
# 0    17243
# Name: mode, dtype: int64

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='mode', data=df)
plt.title('Distribution of Mode Songs', fontsize=10, fontweight='bold')  
plt.xlabel('Mode', fontsize=10) 
plt.ylabel('Count', fontsize=10)  
plt.xticks(fontsize=8) 
plt.yticks(fontsize=8) 

total = len(df['mode'])
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{height / total * 100:.1f}%', ha='center', fontsize=10, fontweight='bold')

plt.show()

# %% [markdown]
# ### 16. Count

# %%
df['count'].describe()
# Out:
# count    74410.000000
# mean        22.338758
# std         62.930165
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         17.000000
# max       3169.000000
# Name: count, dtype: float64

# %%
df['count'].value_counts(ascending=False)
# Out:
# 2       20471
# 4        8153
# 1        5523
# 6        4744
# 8        3312
#         ...
# 476         1
# 263         1
# 314         1
# 360         1
# 2422        1
# Name: count, Length: 379, dtype: int64

# %%
df['count'].nunique()
# Out:
# 379

# %%
histogram_plot(df, 'count', 'Count', 'Distribution of Count Scores')

# %%
boxplot_plot(
    data=df,
    column_name='count',
    xlabel='Count',
    title='Boxplot of Count Scores'
)

# %%
correlation_matrix = df.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, mask=mask)
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.title('Correlation Matrix', fontsize=12, fontweight='bold')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74410 entries, 0 to 28679
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            74410 non-null  object
#  1   artists           74410 non-null  object
#  2   acousticness      74410 non-null  float64
#  3   danceability      74410 non-null  float64
#  4   duration_ms       74410 non-null  float64
#  5   energy            74410 non-null  float64
#  6   instrumentalness  74410 non-null  float64
#  7   liveness          74410 non-null  float64
#  8   loudness          74410 non-null  float64
#  9   speechiness       74410 non-null  float64
#  10  tempo             74410 non-null  float64
#  11  valence           74410 non-null  float64
#  12  popularity        74410 non-null  float64
#  13  key               74410 non-null  int64
#  14  mode              74410 non-null  int64
#  15  count             74410 non-null  int64
#  16  duration_min      74410 non-null  float64
# dtypes: float64(12), int64(3), object(2)
# memory usage: 10.2+ MB

# %%
df.to_csv(r"C:\Users\honey\OneDrive\Masaüstü\Vodafone\genre_df.csv", index=False)
